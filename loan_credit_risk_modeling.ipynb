# %% [markdown]
# <h1 align='center' style='color:green'>Loan Credit Risk Modeling Project</h1>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# display formatting for floating-point numbers in both pandas and NumPy.
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))
np.set_printoptions(suppress = True)

# %% [markdown]
# #### Load Data

# %%
df_customers = pd.read_csv('dataset/customers.csv')
df_loans = pd.read_csv('dataset/loans.csv')
df_bureau = pd.read_csv('dataset/bureau_data.csv')

# %%
df_customers.shape, df_loans.shape, df_bureau.shape
# Out:
# ((50000, 12), (50000, 15), (50000, 8))

# %%
df_customers.head()
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#          state  zipcode
# 0        Delhi   110001
# 1   Tamil Nadu   600001
# 2  West Bengal   700001
# 3    Karnataka   560001
# 4  Maharashtra   411001

# %%
df_loans.head()
# Out:
#   loan_id cust_id loan_purpose  loan_type  sanction_amount  loan_amount  \
# 0  L00001  C00001         Auto    Secured          3004000      2467000
# 1  L00002  C00002         Home    Secured          4161000      3883000
# 2  L00003  C00003     Personal  Unsecured          2401000      2170000
# 3  L00004  C00004     Personal  Unsecured          2345000      1747000
# 4  L00005  C00005         Auto    Secured          4647000      4520000
#
#    processing_fee     gst  net_disbursement  loan_tenure_months  \
# 0       49340.000  444060           1973600                  33
# 1       77660.000  698940           3106400                  30
# 2       43400.000  390600           1736000                  21
# 3       34940.000  314460           1397600                   6
# 4       90400.000  813600           3616000                  28
#
#    principal_outstanding  bank_balance_at_application disbursal_date  \
# 0                1630408                       873386     2019-07-24
# 1                 709309                       464100     2019-07-24
# 2                1562399                      1476042     2019-07-24
# 3                1257839                      1031094     2019-07-24
# 4                1772334                      1032458     2019-07-24
#
#   installment_start_dt  default
# 0           2019-08-10    False
# 1           2019-08-15    False
# 2           2019-08-21    False
# 3           2019-08-09    False
# 4           2019-08-02    False

# %%
df_bureau.head()
# Out:
#   cust_id  number_of_open_accounts  number_of_closed_accounts  \
# 0  C00001                        1                          1
# 1  C00002                        3                          1
# 2  C00003                        2                          1
# 3  C00004                        3                          0
# 4  C00005                        4                          2
#
#    total_loan_months  delinquent_months  total_dpd  enquiry_count  \
# 0                 42                  0          0              3
# 1                 96                 12         60              5
# 2                 82                 24        147              6
# 3                115                 15         87              5
# 4                120                  0          0              5
#
#    credit_utilization_ratio
# 0                         7
# 1                         4
# 2                        58
# 3                        26
# 4                        10

# %%
df = pd.merge(df_customers, df_loans, on = 'cust_id')
df.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'default'],
#       dtype='object')

# %%
df = pd.merge(df, df_bureau, on ='cust_id')
df.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'default',
#        'number_of_open_accounts', 'number_of_closed_accounts',
#        'total_loan_months', 'delinquent_months', 'total_dpd', 'enquiry_count',
#        'credit_utilization_ratio'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      50000 non-null  object
#  1   age                          50000 non-null  int64
#  2   gender                       50000 non-null  object
#  3   marital_status               50000 non-null  object
#  4   employment_status            50000 non-null  object
#  5   income                       50000 non-null  int64
#  6   number_of_dependants         50000 non-null  int64
#  7   residence_type               49938 non-null  object
#  8   years_at_current_address     50000 non-null  int64
#  9   city                         50000 non-null  object
#  10  state                        50000 non-null  object
#  11  zipcode                      50000 non-null  int64
#  12  loan_id                      50000 non-null  object
#  13  loan_purpose                 50000 non-null  object
#  14  loan_type                    50000 non-null  object
#  15  sanction_amount              50000 non-null  int64
#  16  loan_amount                  50000 non-null  int64
#  17  processing_fee               50000 non-null  float64
#  18  gst                          50000 non-null  int64
#  19  net_disbursement             50000 non-null  int64
#  20  loan_tenure_months           50000 non-null  int64
#  21  principal_outstanding        50000 non-null  int64
#  22  bank_balance_at_application  50000 non-null  int64
#  23  disbursal_date               50000 non-null  object
#  24  installment_start_dt         50000 non-null  object
#  25  default                      50000 non-null  bool
#  26  number_of_open_accounts      50000 non-null  int64
#  27  number_of_closed_accounts    50000 non-null  int64
#  28  total_loan_months            50000 non-null  int64
#  29  delinquent_months            50000 non-null  int64
#  30  total_dpd                    50000 non-null  int64
#  31  enquiry_count                50000 non-null  int64
#  32  credit_utilization_ratio     50000 non-null  int64
# dtypes: bool(1), float64(1), int64(19), object(12)
# memory usage: 12.6+ MB

# %%
df['default'].unique()
# Out:
# array([False,  True])

# %%
df['default'] = df['default'].astype(int)
df['default'].unique()
# Out:
# array([0, 1])

# %%
df.default.value_counts()
# Out:
# 0    45703
# 1     4297
# Name: default, dtype: int64

# %% [markdown]
# Clearly, we can see that there is class imbalncing in the data. If, it effects model perfomance then we can treat imbalance.

# %% [markdown]
# #### Train, Test and Split

# %% [markdown]
# We perform train test split before doing EDA to prevent data leakage. We don't want test set to influence EDA or any decisions on feature engineering.

# %%
X = df.drop('default', axis = 1)
y = df['default']

X_train, X_test, y_train, y_test = train_test_split(X,y, stratify = y, test_size = 0.25, random_state = 42)

df_train = pd.concat([X_train, y_train], axis = 1)
df_test = pd.concat([X_test, y_test], axis= 1)

df_train.head()
# Out:
#       cust_id  age gender marital_status employment_status    income  \
# 12746  C12747   59      M        Married     Self-Employed  11327000
# 32495  C32496   44      F         Single          Salaried    715000
# 43675  C43676   38      M         Single          Salaried   3195000
# 9040   C09041   42      M        Married          Salaried   1500000
# 13077  C13078   58      M        Married     Self-Employed   1817000
#
#        number_of_dependants residence_type  years_at_current_address  \
# 12746                     3          Owned                        30
# 32495                     0          Owned                        27
# 43675                     0       Mortgage                        26
# 9040                      2       Mortgage                        30
# 13077                     4          Owned                        29
#
#             city  ... disbursal_date  installment_start_dt  \
# 12746  Hyderabad  ...     2020-10-31            2020-11-11
# 32495     Mumbai  ...     2022-10-22            2022-10-27
# 43675    Chennai  ...     2023-12-04            2023-12-29
# 9040   Bangalore  ...     2020-06-18            2020-07-07
# 13077       Pune  ...     2020-11-12            2020-12-07
#
#       number_of_open_accounts number_of_closed_accounts total_loan_months  \
# 12746                       4                         2               152
# 32495                       3                         1               160
# 43675                       1                         1                54
# 9040                        3                         0                76
# 13077                       1                         2                60
#
#        delinquent_months  total_dpd  enquiry_count  credit_utilization_ratio  \
# 12746                 20        118              4                        36
# 32495                 10         62              5                         5
# 43675                 12         67              4                         0
# 9040                   0          0              8                        87
# 13077                  0          0              1                        71
#
#        default
# 12746        0
# 32495        0
# 43675        0
# 9040         0
# 13077        0
#
# [5 rows x 33 columns]

# %% [markdown]
# <h3 align="center" style="color:green">Data Cleaning</h3>

# %% [markdown]
# #### Handle Missing & Duplicate Values

# %%
df_train.shape
# Out:
# (37500, 33)

# %%
df_train.isna().sum()
# Out:
# cust_id                         0
# age                             0
# gender                          0
# marital_status                  0
# employment_status               0
# income                          0
# number_of_dependants            0
# residence_type                 47
# years_at_current_address        0
# city                            0
# state                           0
# zipcode                         0
# loan_id                         0
# loan_purpose                    0
# loan_type                       0
# sanction_amount                 0
# loan_amount                     0
# processing_fee                  0
# gst                             0
# net_disbursement                0
# loan_tenure_months              0
# principal_outstanding           0
# bank_balance_at_application     0
# disbursal_date                  0
# installment_start_dt            0
# number_of_open_accounts         0
# number_of_closed_accounts       0
# total_loan_months               0
# delinquent_months               0
# total_dpd                       0
# enquiry_count                   0
# credit_utilization_ratio        0
# default                         0
# dtype: int64

# %%
df_train.residence_type.unique()
# Out:
# array(['Owned', 'Mortgage', 'Rented', nan], dtype=object)

# %%
mode_residence = df_train.residence_type.mode()[0]
mode_residence
# Out:
# 'Owned'

# %%
df_train.residence_type.fillna(mode_residence, inplace=True)
df_test.residence_type.fillna(mode_residence, inplace =True)

df_train.residence_type.unique(), df_test.residence_type.unique()
# Out:
# (array(['Owned', 'Mortgage', 'Rented'], dtype=object),
#  array(['Owned', 'Mortgage', 'Rented'], dtype=object))

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default'],
#       dtype='object')

# %%
columns_continuous = df.select_dtypes(include=['number']).columns.tolist()
columns_categorical = df.select_dtypes(include = ['object', 'category']).columns.tolist()


columns_continuous = [col for col in columns_continuous if col not in ['zipcode', 'default']]
columns_categorical = [col for col in columns_categorical if col not in ['cust_id', 'loan_id', 'disbursal_date', 'installment_start_dt']]
columns_categorical.extend(['zipcode', 'default'])



print(columns_continuous)
print(columns_categorical)
# Out:
# ['age', 'income', 'number_of_dependants', 'years_at_current_address', 'sanction_amount', 'loan_amount', 'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months', 'principal_outstanding', 'bank_balance_at_application', 'number_of_open_accounts', 'number_of_closed_accounts', 'total_loan_months', 'delinquent_months', 'total_dpd', 'enquiry_count', 'credit_utilization_ratio']
# ['gender', 'marital_status', 'employment_status', 'residence_type', 'city', 'state', 'loan_purpose', 'loan_type', 'zipcode', 'default']

# %% [markdown]
# #### Box plot to visualize outliers

# %%
num_plots = len(columns_continuous)
num_cols = 4
num_rows = (num_plots + num_cols - 1) // num_cols

fig, axes = plt.subplots(num_rows, num_cols, figsize = (5 * num_cols, 5* num_rows))
axes = axes.flatten()

for i, col in enumerate(columns_continuous):
    sns.boxplot(y=df_train[col], ax = axes[i], color = 'green')
    axes[i].set_title(col)
for j in range(i+1, num_rows * num_cols):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
num_plots = len(columns_continuous)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(columns_continuous):
    sns.histplot(df_train[col], ax=axes[i], color = 'green')
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Outlier removal : Processing Fee

# %%
df_train.processing_fee.describe()
# Out:
# count     37500.000
# mean      80290.677
# std      113128.140
# min           0.000
# 25%       19220.000
# 50%       44600.000
# 75%       92420.000
# max     5293543.524
# Name: processing_fee, dtype: float64

# %%
df_train[(df_train.processing_fee/df_train.loan_amount)> 0.03][['loan_amount','processing_fee']]
# Out:
#        loan_amount  processing_fee
# 23981      2234000     2669791.023
# 28174       966000     1214492.673
# 47089      1738000     1858964.768
# 29305      2616000     3036378.005
# 9898       3626000     5293543.524

# %%
df_train_1 = df_train[df_train.processing_fee/df_train.loan_amount< 0.03].copy()
df_test = df_test[df_test.processing_fee/df_test.loan_amount<0.03].copy()
df_test.shape, df_train_1.shape
# Out:
# ((12497, 33), (37488, 33))

# %%
# Use other business rules for data validation
# Rule 1: GST should not be more than 20%

df_train_1[(df_train_1.gst/df_train_1.loan_amount)>0.2].shape
# Out:
# (0, 33)

# %%
# Rule 2: Net disbursement should not be higher than loan_amount
df_train_1[df_train_1.net_disbursement>df_train_1.loan_amount].shape
# Out:
# (0, 33)

# %% [markdown]
# No rows found that breaks rule 1 and rule 2

# %% [markdown]
# #### Analyze Categorical Columns

# %%
columns_categorical
# Out:
# ['gender',
#  'marital_status',
#  'employment_status',
#  'residence_type',
#  'city',
#  'state',
#  'loan_purpose',
#  'loan_type',
#  'zipcode',
#  'default']

# %%
for col in columns_categorical:
    print(col, "-->", df_train_1[col].unique())
# Out:
# gender --> ['M' 'F']
# marital_status --> ['Married' 'Single']
# employment_status --> ['Self-Employed' 'Salaried']
# residence_type --> ['Owned' 'Mortgage' 'Rented']
# city --> ['Hyderabad' 'Mumbai' 'Chennai' 'Bangalore' 'Pune' 'Kolkata' 'Ahmedabad'
#  'Delhi' 'Lucknow' 'Jaipur']
# state --> ['Telangana' 'Maharashtra' 'Tamil Nadu' 'Karnataka' 'West Bengal'
#  'Gujarat' 'Delhi' 'Uttar Pradesh' 'Rajasthan']
# loan_purpose --> ['Home' 'Education' 'Personal' 'Auto' 'Personaal']
# loan_type --> ['Secured' 'Unsecured']
# zipcode --> [500001 400001 600001 560001 411001 700001 380001 110001 226001 302001]
# default --> [0 1]

# %% [markdown]
# #### Fix errors in Loan Purpose Column

# %%
df_train_1['loan_purpose'] = df_train_1['loan_purpose'].replace('Personaal', 'Personal')
df_train_1['loan_purpose'].unique()
# Out:
# array(['Home', 'Education', 'Personal', 'Auto'], dtype=object)

# %%
df_test['loan_purpose'] = df_test['loan_purpose'].replace('Personaal', 'Personal')
df_test['loan_purpose'].unique()
# Out:
# array(['Home', 'Education', 'Auto', 'Personal'], dtype=object)

# %% [markdown]
# <h3 style="color:Green" align="center">Exploratory Data Analysis</h3>

# %%
columns_continuous
# Out:
# ['age',
#  'income',
#  'number_of_dependants',
#  'years_at_current_address',
#  'sanction_amount',
#  'loan_amount',
#  'processing_fee',
#  'gst',
#  'net_disbursement',
#  'loan_tenure_months',
#  'principal_outstanding',
#  'bank_balance_at_application',
#  'number_of_open_accounts',
#  'number_of_closed_accounts',
#  'total_loan_months',
#  'delinquent_months',
#  'total_dpd',
#  'enquiry_count',
#  'credit_utilization_ratio']

# %% [markdown]
# #### Age column

# %%
df_train_1.groupby("default")['age'].describe()
# Out:
#             count   mean   std    min    25%    50%    75%    max
# default
# 0       34265.000 39.768 9.880 18.000 33.000 40.000 46.000 70.000
# 1        3223.000 37.125 9.290 18.000 31.000 37.000 44.000 70.000

# %% [markdown]
# **Insights**
#
# 1. Average age in the default group is little less (37.12) than the average (39.7) of the group that did not default
# 1. Variability (standard deviation) is mostly similar in both the groups
# 1. Both the groups have similar min and max ages

# %% [markdown]
# #### KDE for all the Columns

# %%
plt.figure(figsize=(24, 20))  # Width, height in inches

for i, col in enumerate(columns_continuous):
    plt.subplot(6, 4, i+1)  # 1 row, 4 columns, ith subplot
    sns.kdeplot(df_train_1[col][df_train_1['default']==0], fill=True, label='default=0')
    sns.kdeplot(df_train_1[col][df_train_1['default']==1], fill=True, label='default=1')
    plt.title(col)        
    plt.xlabel('')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. In columns: loan_tenure_months, delinquent_months, total_dpd, credit_utilization, higher values indicate high likelyhood of becoming a default. Hence these 4 looks like strong predictors
# 1. In remaining columns the distributions do not give any obvious insights
# 1. Why loan_amount and income did not give any signs of being strong predictors? May be when we combine these two and get loan to income ratio (LTI), that may have influence on the target variable. We will explore more later

# %% [markdown]
# <h3 style="color:Green" align="center">Feature Engineering, Feature Selection</h3>

# %% [markdown]
# #### General Loan to Income (LTI) Ratio

# %%
df_train_1[['loan_amount', 'income']].head()
# Out:
#        loan_amount    income
# 12746     23442000  11327000
# 32495      1149000    715000
# 43675     11296000   3195000
# 9040       1695000   1500000
# 13077       905000   1817000

# %%
df_test.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default'],
#       dtype='object')

# %%
df_train_1['loan_to_income'] = round(df_train_1['loan_amount'] / df_train_1['income'], 2)
df_test['loan_to_income'] = round(df_test['loan_amount'] / df_test['income'], 2)
df_train_1['loan_to_income'].describe()
# Out:
# count   37488.000
# mean        1.557
# std         0.974
# min         0.300
# 25%         0.770
# 50%         1.160
# 75%         2.460
# max         4.570
# Name: loan_to_income, dtype: float64

# %%
plt.figure(figsize = (8,4))
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default'] == 0], fill = True, label = 'default = 0')
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default'] == 1], fill = True, label = 'default = 1')
plt.title(f'Loan to Income Ratio (LTI) KDE Plot with Hue by Default')
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
# 1. Blue graph has majority of its values on lower side of LTI
# 2. Orange graph has many values when LTI is higher indicating that higher LTI means high risk loan

# %% [markdown]
# #### Generate Delinquency Ratio

# %%
df_train_1['delinquency_ratio'] = (df_train_1['delinquent_months']*100 / df_train_1['total_loan_months']).round(1)
df_test['delinquency_ratio'] = (df_test['delinquent_months']*100 / df_test['total_loan_months']).round(1)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
# 1. Blue graph has majority of its values on lower side of LTI
# 2. Orange graph has many values when delinquency ratio is higher indicating some correlation on default

# %% [markdown]
# #### Generate Avg DPD Per Delinquency

# %%
df_train_1['avg_dpd_per_delinquency'] = np.where(
    df_train_1['delinquent_months'] != 0,
    (df_train_1['total_dpd'] / df_train_1['delinquent_months']).round(1),
    0
)

df_test['avg_dpd_per_delinquency'] = np.where(
    df_test['delinquent_months'] != 0,
    (df_test['total_dpd'] / df_test['delinquent_months']).round(1),
    0
)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Avg DPD Per Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. Graph clearly shows more occurances of default cases when avg_dpd_per_delinquency is high. This means this column is a strong predictor

# %% [markdown]
# #### Remove columns that are just unique ids and don't have influence on target

# %%
df_train_1.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default',
#        'loan_to_income', 'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_train_2 = df_train_1.drop(['cust_id', 'loan_id'],axis="columns")
df_test = df_test.drop(['cust_id', 'loan_id'],axis="columns")

# %% [markdown]
# #### Remove columns that don't have effect on our predictor, and removing few columns which have alredy used to create ne columns

# %%
df_train_3 = df_train_2.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_test = df_test.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_train_3.columns
# Out:
# Index(['age', 'gender', 'marital_status', 'employment_status',
#        'number_of_dependants', 'residence_type', 'years_at_current_address',
#        'city', 'state', 'zipcode', 'loan_purpose', 'loan_type',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
col_to_scale = df_train_3.select_dtypes(['int64', 'float64']).columns.tolist()
col_to_scale = [col for col in col_to_scale if col not in ['zipcode', 'default']]
col_to_scale
# Out:
# ['age',
#  'number_of_dependants',
#  'years_at_current_address',
#  'sanction_amount',
#  'processing_fee',
#  'gst',
#  'net_disbursement',
#  'loan_tenure_months',
#  'principal_outstanding',
#  'bank_balance_at_application',
#  'number_of_open_accounts',
#  'number_of_closed_accounts',
#  'enquiry_count',
#  'credit_utilization_ratio',
#  'loan_to_income',
#  'delinquency_ratio',
#  'avg_dpd_per_delinquency']

# %% [markdown]
# #### VIF to Measure multicolinearity

# %%
X_train = df_train_3.drop('default', axis = 1)
y_train = df_train_3['default']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

X_train[col_to_scale] = scaler.fit_transform(X_train[col_to_scale])
X_train.describe()
# Out:
#             age  number_of_dependants  years_at_current_address    zipcode  \
# count 37488.000             37488.000                 37488.000  37488.000
# mean      0.414                 0.389                     0.500 418876.240
# std       0.190                 0.307                     0.297 169029.868
# min       0.000                 0.000                     0.000 110001.000
# 25%       0.288                 0.000                     0.233 302001.000
# 50%       0.404                 0.400                     0.500 400001.000
# 75%       0.538                 0.600                     0.767 560001.000
# max       1.000                 1.000                     1.000 700001.000
#
#        sanction_amount  processing_fee       gst  net_disbursement  \
# count        37488.000       37488.000 37488.000         37488.000
# mean             0.089           0.083     0.083             0.083
# std              0.120           0.112     0.112             0.112
# min              0.000           0.000     0.000             0.000
# 25%              0.021           0.019     0.019             0.019
# 50%              0.049           0.046     0.046             0.046
# 75%              0.098           0.096     0.096             0.096
# max              1.000           1.000     1.000             1.000
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count           37488.000              37488.000                    37488.000
# mean                0.377                  0.262                        0.124
# std                 0.235                  0.244                        0.133
# min                 0.000                  0.000                        0.000
# 25%                 0.189                  0.078                        0.034
# 50%                 0.340                  0.194                        0.083
# 75%                 0.547                  0.352                        0.155
# max                 1.000                  1.000                        1.000
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                37488.000                  37488.000      37488.000
# mean                     0.501                      0.501          0.501
# std                      0.373                      0.407          0.254
# min                      0.000                      0.000          0.000
# 25%                      0.000                      0.000          0.375
# 50%                      0.667                      0.500          0.500
# 75%                      1.000                      1.000          0.625
# max                      1.000                      1.000          1.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                 37488.000       37488.000          37488.000
# mean                      0.439           0.294              0.103
# std                       0.297           0.228              0.173
# min                       0.000           0.000              0.000
# 25%                       0.182           0.110              0.000
# 50%                       0.394           0.201              0.037
# 75%                       0.677           0.506              0.129
# max                       1.000           1.000              1.000
#
#        avg_dpd_per_delinquency
# count                37488.000
# mean                     0.328
# std                      0.291
# min                      0.000
# 25%                      0.000
# 50%                      0.430
# 75%                      0.573
# max                      1.000

# %% [markdown]
# #### Same transformation on test set

# %%
X_test = df_test.drop('default', axis='columns')
y_test = df_test['default']

X_test[col_to_scale] = scaler.transform(X_test[col_to_scale])
X_test.describe()
# Out:
#             age  number_of_dependants  years_at_current_address    zipcode  \
# count 12497.000             12497.000                 12497.000  12497.000
# mean      0.415                 0.385                     0.503 419759.822
# std       0.189                 0.307                     0.298 168845.353
# min       0.000                 0.000                     0.000 110001.000
# 25%       0.288                 0.000                     0.233 302001.000
# 50%       0.423                 0.400                     0.500 411001.000
# 75%       0.538                 0.600                     0.767 560001.000
# max       1.000                 1.000                     1.000 700001.000
#
#        sanction_amount  processing_fee       gst  net_disbursement  \
# count        12497.000       12497.000 12497.000         12497.000
# mean             0.089           0.083     0.083             0.083
# std              0.121           0.113     0.113             0.113
# min             -0.000          -0.000    -0.000            -0.000
# 25%              0.021           0.019     0.019             0.019
# 50%              0.050           0.046     0.046             0.046
# 75%              0.097           0.095     0.095             0.095
# max              0.981           0.964     0.964             0.964
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count           12497.000              12497.000                    12497.000
# mean                0.375                  0.265                        0.125
# std                 0.234                  0.245                        0.135
# min                 0.000                  0.000                        0.001
# 25%                 0.189                  0.080                        0.034
# 50%                 0.340                  0.198                        0.084
# 75%                 0.547                  0.357                        0.158
# max                 1.000                  1.000                        0.939
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                12497.000                  12497.000      12497.000
# mean                     0.497                      0.500          0.501
# std                      0.373                      0.407          0.254
# min                      0.000                      0.000          0.000
# 25%                      0.000                      0.000          0.375
# 50%                      0.333                      0.500          0.500
# 75%                      0.667                      1.000          0.625
# max                      1.000                      1.000          1.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                 12497.000       12497.000          12497.000
# mean                      0.436           0.293              0.106
# std                       0.295           0.226              0.173
# min                       0.000           0.000              0.000
# 25%                       0.182           0.112              0.000
# 50%                       0.394           0.201              0.042
# 75%                       0.677           0.499              0.134
# max                       1.000           1.005              1.000
#
#        avg_dpd_per_delinquency
# count                12497.000
# mean                     0.334
# std                      0.290
# min                      0.000
# 25%                      0.000
# 50%                      0.440
# 75%                      0.580
# max                      1.000

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Column'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values,i) for i in range (data.shape[1])]
    return vif_df

# %%
calculate_vif(X_train[col_to_scale])
# Out:
# /Users/kasimajji/.pyenv/versions/3.11.4/lib/python3.11/site-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                          Column     VIF
# 0                           age   5.555
# 1          number_of_dependants   2.723
# 2      years_at_current_address   3.361
# 3               sanction_amount 101.084
# 4                processing_fee     inf
# 5                           gst     inf
# 6              net_disbursement     inf
# 7            loan_tenure_months   6.170
# 8         principal_outstanding  16.317
# 9   bank_balance_at_application   9.326
# 10      number_of_open_accounts   4.380
# 11    number_of_closed_accounts   2.365
# 12                enquiry_count   6.333
# 13     credit_utilization_ratio   2.896
# 14               loan_to_income   6.893
# 15            delinquency_ratio   1.931
# 16      avg_dpd_per_delinquency   2.903

# %%
features_to_drop_vif = ['sanction_amount', 'processing_fee', 'gst', 'net_disbursement','principal_outstanding']


X_train_1 = X_train.drop(features_to_drop_vif, axis='columns')
numeric_columns = X_train_1.select_dtypes(['int64', 'float64']).columns
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
vif_df = calculate_vif(X_train_1[numeric_columns])

# %%
selected_numeric_features_vif = vif_df.Column.values
selected_numeric_features_vif
# Out:
# array(['age', 'number_of_dependants', 'years_at_current_address',
#        'zipcode', 'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts',
#        'enquiry_count', 'credit_utilization_ratio', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'], dtype=object)

# %%
plt.figure(figsize=(12,12))
cm = df_train_3[numeric_columns.append(pd.Index(['default']))].corr()
sns.heatmap(cm, annot=True, fmt='0.2f')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Feature Selection: Categorical Features

# %%
X_train_1.head()
# Out:
#         age gender marital_status employment_status  number_of_dependants  \
# 12746 0.788      M        Married     Self-Employed                 0.600
# 32495 0.500      F         Single          Salaried                 0.000
# 43675 0.385      M         Single          Salaried                 0.000
# 9040  0.462      M        Married          Salaried                 0.400
# 13077 0.769      M        Married     Self-Employed                 0.800
#
#       residence_type  years_at_current_address       city        state  \
# 12746          Owned                     0.967  Hyderabad    Telangana
# 32495          Owned                     0.867     Mumbai  Maharashtra
# 43675       Mortgage                     0.833    Chennai   Tamil Nadu
# 9040        Mortgage                     0.967  Bangalore    Karnataka
# 13077          Owned                     0.933       Pune  Maharashtra
#
#        zipcode  ...  loan_type loan_tenure_months  \
# 12746   500001  ...    Secured              0.415
# 32495   400001  ...    Secured              0.830
# 43675   600001  ...    Secured              0.491
# 9040    560001  ...    Secured              0.642
# 13077   411001  ...  Unsecured              0.170
#
#        bank_balance_at_application  number_of_open_accounts  \
# 12746                        0.613                    1.000
# 32495                        0.025                    0.667
# 43675                        0.174                    0.000
# 9040                         0.078                    0.667
# 13077                        0.072                    0.000
#
#        number_of_closed_accounts  enquiry_count  credit_utilization_ratio  \
# 12746                      1.000          0.375                     0.364
# 32495                      0.500          0.500                     0.051
# 43675                      0.500          0.375                     0.000
# 9040                       0.000          0.875                     0.879
# 13077                      1.000          0.000                     0.717
#
#        loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# 12746           0.415              0.132                    0.590
# 32495           0.307              0.062                    0.620
# 43675           0.759              0.222                    0.560
# 9040            0.194              0.000                    0.000
# 13077           0.047              0.000                    0.000
#
# [5 rows x 21 columns]

# %%
def calculate_woe_iv(df, feature, target):
    grouped = df.groupby(feature)[target].agg(['count', 'sum'])
    grouped = grouped.rename(columns = {'count': 'total', 'sum': 'good'})
    grouped['bad'] = grouped['total'] - grouped['good']

    total_good = grouped['good'].sum()
    total_bad = grouped['bad'].sum()
    
    grouped['good_pct'] = grouped['good'] / total_good
    grouped['bad_pct'] = grouped['bad'] / total_bad
    grouped['woe'] = np.log(grouped['good_pct']/ grouped['bad_pct'])
    grouped['iv'] = (grouped['good_pct'] -grouped['bad_pct'])*grouped['woe']
    
    grouped['woe'] = grouped['woe'].replace([np.inf, -np.inf], 0)
    grouped['iv'] = grouped['iv'].replace([np.inf, -np.inf], 0)
    
    total_iv = grouped['iv'].sum()
    
    return grouped, total_iv

grouped, total_iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), 'loan_purpose', 'default')
grouped
# Out:
#               total  good    bad  good_pct  bad_pct    woe    iv
# loan_purpose
# Auto           7447   327   7120     0.101    0.208 -0.717 0.076
# Education      5620   559   5061     0.173    0.148  0.161 0.004
# Home          11304  1734   9570     0.538    0.279  0.656 0.170
# Personal      13117   603  12514     0.187    0.365 -0.669 0.119

# %%
X_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37488 entries, 12746 to 37784
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          37488 non-null  float64
#  1   gender                       37488 non-null  object
#  2   marital_status               37488 non-null  object
#  3   employment_status            37488 non-null  object
#  4   number_of_dependants         37488 non-null  float64
#  5   residence_type               37488 non-null  object
#  6   years_at_current_address     37488 non-null  float64
#  7   city                         37488 non-null  object
#  8   state                        37488 non-null  object
#  9   zipcode                      37488 non-null  int64
#  10  loan_purpose                 37488 non-null  object
#  11  loan_type                    37488 non-null  object
#  12  loan_tenure_months           37488 non-null  float64
#  13  bank_balance_at_application  37488 non-null  float64
#  14  number_of_open_accounts      37488 non-null  float64
#  15  number_of_closed_accounts    37488 non-null  float64
#  16  enquiry_count                37488 non-null  float64
#  17  credit_utilization_ratio     37488 non-null  float64
#  18  loan_to_income               37488 non-null  float64
#  19  delinquency_ratio            37488 non-null  float64
#  20  avg_dpd_per_delinquency      37488 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 6.3+ MB

# %%
iv_values = {}

for feature in X_train_1.columns:
    if X_train_1[feature].dtype == 'object':
        _, iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), feature, 'default' )
    else:
        X_binned = pd.cut(X_train_1[feature], bins=10, labels=False)
        _, iv = calculate_woe_iv(pd.concat([X_binned, y_train],axis=1), feature, 'default' )
    iv_values[feature] = iv
        
iv_values
# Out:
# {'age': 0.0890689462679479,
#  'gender': 0.00047449502170914947,
#  'marital_status': 0.001129766845390142,
#  'employment_status': 0.003953046301722585,
#  'number_of_dependants': 0.0019380899135053508,
#  'residence_type': 0.246745268718145,
#  'years_at_current_address': 0.0020800513608156363,
#  'city': 0.0019059578709781529,
#  'state': 0.0019005589806779287,
#  'zipcode': 0.0016677413243392572,
#  'loan_purpose': 0.3691197842282755,
#  'loan_type': 0.16319324904149224,
#  'loan_tenure_months': 0.21893515090196278,
#  'bank_balance_at_application': 0.0063187993277516365,
#  'number_of_open_accounts': 0.08463134083005877,
#  'number_of_closed_accounts': 0.0011964272592421567,
#  'enquiry_count': 0.007864214085342608,
#  'credit_utilization_ratio': 2.352965568168245,
#  'loan_to_income': 0.476415456948364,
#  'delinquency_ratio': 0.716576108689321,
#  'avg_dpd_per_delinquency': 0.40151905412190175}

# %%
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))

iv_df = pd.DataFrame(list(iv_values.items()), columns=['Feature', 'IV'])
iv_df = iv_df.sort_values(by='IV', ascending=False)
iv_df
# Out:
#                         Feature    IV
# 17     credit_utilization_ratio 2.353
# 19            delinquency_ratio 0.717
# 18               loan_to_income 0.476
# 20      avg_dpd_per_delinquency 0.402
# 10                 loan_purpose 0.369
# 5                residence_type 0.247
# 12           loan_tenure_months 0.219
# 11                    loan_type 0.163
# 0                           age 0.089
# 14      number_of_open_accounts 0.085
# 16                enquiry_count 0.008
# 13  bank_balance_at_application 0.006
# 3             employment_status 0.004
# 6      years_at_current_address 0.002
# 4          number_of_dependants 0.002
# 7                          city 0.002
# 8                         state 0.002
# 9                       zipcode 0.002
# 15    number_of_closed_accounts 0.001
# 2                marital_status 0.001
# 1                        gender 0.000

# %%
# select features that has IV > 0.02
selected_features_iv = [feature for feature, iv in iv_values.items() if iv > 0.02]
selected_features_iv
# Out:
# ['age',
#  'residence_type',
#  'loan_purpose',
#  'loan_type',
#  'loan_tenure_months',
#  'number_of_open_accounts',
#  'credit_utilization_ratio',
#  'loan_to_income',
#  'delinquency_ratio',
#  'avg_dpd_per_delinquency']

# %% [markdown]
# #### Feature Encoding

# %%
X_train_reduced = X_train_1[selected_features_iv]
X_test_reduced = X_test[selected_features_iv]

# %%
X_train_encoded = pd.get_dummies(X_train_reduced, drop_first=True)
X_train_encoded.head(3)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 12746 0.788               0.415                    1.000
# 32495 0.500               0.830                    0.667
# 43675 0.385               0.491                    0.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 12746                     0.364           0.415              0.132
# 32495                     0.051           0.307              0.062
# 43675                     0.000           0.759              0.222
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 12746                    0.590                     1                      0
# 32495                    0.620                     1                      0
# 43675                    0.560                     0                      0
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 12746                       0                  1                      0
# 32495                       1                  0                      0
# 43675                       0                  1                      0
#
#        loan_type_Unsecured
# 12746                    0
# 32495                    0
# 43675                    0

# %%
X_test_encoded = pd.get_dummies(X_test_reduced, drop_first=True)
X_test_encoded.head(3)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346               0.755                    0.333
# 15514 0.481               0.226                    1.000
# 30367 0.231               0.547                    0.667
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 19205                     0.990           0.550              0.000
# 15514                     0.323           0.220              0.000
# 30367                     0.828           0.180              0.000
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 19205                    0.000                     1                      0
# 15514                    0.000                     1                      0
# 30367                    0.000                     1                      0
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 19205                       0                  1                      0
# 15514                       1                  0                      0
# 30367                       0                  0                      0
#
#        loan_type_Unsecured
# 19205                    0
# 15514                    0
# 30367                    0

# %% [markdown]
# <h3 align="center" style="color:Green">Model Training</h3>

# %% [markdown]
# ### Attempt 1
#
# 1. Logistic Regression, RandomForest & XGB
# 1. No handling of class imbalance

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

model = LogisticRegression()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.85      0.72      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.85      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
feature_importance = model.coef_[0]

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_encoded.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

coef_df
# Out:
#                           Coefficients
# residence_type_Owned            -1.468
# loan_purpose_Home               -1.385
# age                             -0.531
# loan_tenure_months               0.398
# number_of_open_accounts          0.636
# loan_purpose_Personal            0.639
# loan_type_Unsecured              0.639
# loan_purpose_Education           0.993
# residence_type_Rented            1.445
# avg_dpd_per_delinquency          1.970
# delinquency_ratio                9.440
# loan_to_income                  10.686
# credit_utilization_ratio        12.646

# %%
# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.86      0.71      0.78      1074
#
#     accuracy                           0.97     12497
#    macro avg       0.92      0.85      0.88     12497
# weighted avg       0.96      0.97      0.96     12497

# %% [markdown]
# #### XGBoost

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.82      0.76      0.79      1074
#
#     accuracy                           0.97     12497
#    macro avg       0.90      0.87      0.89     12497
# weighted avg       0.96      0.97      0.96     12497

# %% [markdown]
# Since there is not much difference between XGB and Logistic, we will choose LogisticRegression as a candidate for our RandomizedSearchCV candidate it has a better interpretation.

# %% [markdown]
# #### RandomizedSearch CV for Attempt 1: Logistic Regression

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import numpy as np

# Hyperparameter distribution for RandomizedSearchCV
param_dist = {
    'C': np.logspace(-4, 4, 20),
    'solver': ['lbfgs', 'saga', 'liblinear', 'newton-cg']
}

# Create the Logistic Regression model
log_reg = LogisticRegression(max_iter=10000)  # Increased max_iter for convergence

# Set up RandomizedSearchCV without verbose
random_search = RandomizedSearchCV(
    estimator=log_reg,
    param_distributions=param_dist,
    n_iter=50,  # Number of parameter settings that are sampled
    scoring='f1',
    cv=3,  # 3-fold cross-validation
    random_state=42,  # Set a random state for reproducibility
    n_jobs=-1  # Use all available cores
)

# Fit the RandomizedSearchCV to the training data
random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

# Get the best model from the search
best_model = random_search.best_estimator_

# Make predictions on the test data
y_pred = best_model.predict(X_test_encoded)

# Print the classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Best Parameters: {'solver': 'liblinear', 'C': 1438.44988828766}
# Best Score: 0.7578820896729832
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     11423
#            1       0.83      0.74      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.90      0.86      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# #### RandomizedSearch CV for Attempt 1: XGBoost

# %%
from scipy.stats import uniform, randint
from sklearn.model_selection import RandomizedSearchCV

# Define parameter distribution for RandomizedSearchCV
param_dist = {
    'n_estimators': [100, 150, 200, 250, 300],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'learning_rate': [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3],
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'scale_pos_weight': [1, 2, 3, 5, 7, 10],
    'reg_alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0],  # L1 regularization term
    'reg_lambda': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]  # L2 regularization term
}

xgb = XGBClassifier()

random_search = RandomizedSearchCV(estimator=xgb, param_distributions=param_dist, n_iter=100,
                                   scoring='f1', cv=3, verbose=1, n_jobs=-1, random_state=42)

random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best Parameters: {'subsample': 0.7, 'scale_pos_weight': 2, 'reg_lambda': 10.0, 'reg_alpha': 0.01, 'n_estimators': 100, 'max_depth': 4, 'learning_rate': 0.2, 'colsample_bytree': 0.8}
# Best Score: 0.7885351531443989
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.76      0.84      0.80      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.87      0.91      0.89     12497
# weighted avg       0.97      0.96      0.96     12497

# %% [markdown]
# ### Attempt 2
#
# 1. Logistic Regression & XGB
# 1. Handle Class Imbalance Using Under Sampling

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42)
X_train_res, y_train_res = rus.fit_resample(X_train_encoded, y_train)
y_train_res.value_counts()
# Out:
# 0    3223
# 1    3223
# Name: default, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.51      0.96      0.67      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.75      0.93      0.81     12497
# weighted avg       0.95      0.92      0.93     12497

# %%
model = XGBClassifier(**random_search.best_params_)
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.52      0.98      0.68      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.76      0.95      0.82     12497
# weighted avg       0.96      0.92      0.93     12497

# %% [markdown]
# ### Attempt 3
#
# 1. Logistic Regression
# 1. Handle Class Imbalance Using SMOTE Tomek
# 1. Parameter tunning using optuna

# %%
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=42)
X_train_smt, y_train_smt = smt.fit_resample(X_train_encoded, y_train)
y_train_smt.value_counts()
# Out:
# 0    34195
# 1    34195
# Name: default, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train_smt, y_train_smt)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.55      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.77      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
import optuna
from sklearn.metrics import make_scorer, f1_score
from sklearn.model_selection import cross_val_score

# %%
# Define the objective function for Optuna
def objective(trial):
    param = {
        'C': trial.suggest_float('C', 1e-4, 1e4, log=True),  # Logarithmically spaced values
        'solver': trial.suggest_categorical('solver', ['lbfgs', 'liblinear', 'saga', 'newton-cg']),  # Solvers
        'tol': trial.suggest_float('tol', 1e-6, 1e-1, log=True),  # Logarithmically spaced values for tolerance
        'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced'])  # Class weights
    }

    model = LogisticRegression(**param, max_iter=10000)
    
    # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=-1)
    
    return np.mean(scores)

study_logistic = optuna.create_study(direction='maximize')
study_logistic.optimize(objective, n_trials=50)
# Out:
# [I 2025-04-19 13:04:33,900] A new study created in memory with name: no-name-e0146614-8161-4d04-8104-1dcb6c6f541c
# [I 2025-04-19 13:04:34,143] Trial 0 finished with value: 0.9268341218109565 and parameters: {'C': 0.007109714387651174, 'solver': 'lbfgs', 'tol': 0.00011382034526468229, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.9268341218109565.
# [I 2025-04-19 13:04:34,328] Trial 1 finished with value: 0.9367534910207325 and parameters: {'C': 8488.803098175884, 'solver': 'lbfgs', 'tol': 0.003182076217494311, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9367534910207325.
# [I 2025-04-19 13:04:34,499] Trial 2 finished with value: 0.9367534323514359 and parameters: {'C': 27.86732335527608, 'solver': 'lbfgs', 'tol': 0.0033994639320306893, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.9367534910207325.
# [I 2025-04-19 13:04:34,740] Trial 3 finished with value: 0.945751855668977 and parameters: {'C': 6.614055179340405, 'solver': 'saga', 'tol': 0.00015896769549298862, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.945751855668977.
# [I 2025-04-19 13:04:34,973] Trial 4 finished with value: 0.9456501602503419 and parameters: {'C': 824.6324179474652, 'solver': 'newton-cg', 'tol': 9.260814745366403e-06, 'class_weight': None}. Best is trial 3 with value: 0.945751855668977.
# [I 2025-04-19 13:04:35,173] Trial 5 finished with value: 0.8507320195591158 and parameters: {'C': 0.0004954342243506505, 'solver': 'liblinear', 'tol': 0.0002519759080859563, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.945751855668977.
# [I 2025-04-19 13:04:35,347] Trial 6 finished with value: 0.8065311337716548 and parameters: {'C': 412.357413892485, 'solver': 'lbfgs', 'tol': 0.04825284920306563, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.945751855668977.
# [I 2025-04-19 13:04:35,541] Trial 7 finished with value: 0.9456936619659766 and parameters: {'C': 12.646271109787474, 'solver': 'lbfgs', 'tol': 7.314403030950762e-05, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.945751855668977.
# [I 2025-04-19 13:04:35,723] Trial 8 finished with value: 0.9453088807193115 and parameters: {'C': 7725.364074495461, 'solver': 'saga', 'tol': 0.04102803722143049, 'class_weight': None}. Best is trial 3 with value: 0.945751855668977.
# [I 2025-04-19 13:04:35,884] Trial 9 finished with value: 0.923235570462151 and parameters: {'C': 13.85262139526178, 'solver': 'lbfgs', 'tol': 0.008859972577934758, 'class_weight': None}. Best is trial 3 with value: 0.945751855668977.
# [I 2025-04-19 13:04:36,182] Trial 10 finished with value: 0.9415353125476926 and parameters: {'C': 0.11799734972408579, 'solver': 'saga', 'tol': 2.1137816679034158e-06, 'class_weight': None}. Best is trial 3 with value: 0.945751855668977.
# [I 2025-04-19 13:04:36,440] Trial 11 finished with value: 0.9456024723558963 and parameters: {'C': 1.0487878472545298, 'solver': 'saga', 'tol': 3.965720295949506e-05, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.945751855668977.
# [I 2025-04-19 13:04:36,663] Trial 12 finished with value: 0.9456170287062928 and parameters: {'C': 1.7758912286165878, 'solver': 'newton-cg', 'tol': 0.0007448924944210999, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.945751855668977.
# [I 2025-04-19 13:04:36,905] Trial 13 finished with value: 0.9373576348570292 and parameters: {'C': 0.06981647736718909, 'solver': 'liblinear', 'tol': 2.3698872511458688e-05, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.945751855668977.
# [I 2025-04-19 13:04:37,129] Trial 14 finished with value: 0.9456938747597355 and parameters: {'C': 26.567880559133076, 'solver': 'saga', 'tol': 0.0006006941032820542, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.945751855668977.
# [I 2025-04-19 13:04:37,345] Trial 15 finished with value: 0.9456938380012504 and parameters: {'C': 94.33361334230018, 'solver': 'saga', 'tol': 0.0007346743154399566, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.945751855668977.
# [I 2025-04-19 13:04:37,562] Trial 16 finished with value: 0.9420782957783601 and parameters: {'C': 0.13674067552821392, 'solver': 'saga', 'tol': 0.0006236217372830173, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.945751855668977.
# [I 2025-04-19 13:04:37,839] Trial 17 finished with value: 0.9457791949281719 and parameters: {'C': 2.0455648297476228, 'solver': 'saga', 'tol': 8.591027379541469e-06, 'class_weight': 'balanced'}. Best is trial 17 with value: 0.9457791949281719.
# [I 2025-04-19 13:04:38,135] Trial 18 finished with value: 0.9277726985898341 and parameters: {'C': 0.007880642329930184, 'solver': 'saga', 'tol': 1.3372140819936163e-06, 'class_weight': None}. Best is trial 17 with value: 0.9457791949281719.
# [I 2025-04-19 13:04:38,415] Trial 19 finished with value: 0.9457790240728992 and parameters: {'C': 1.9259965541570216, 'solver': 'saga', 'tol': 7.3080960969340255e-06, 'class_weight': 'balanced'}. Best is trial 17 with value: 0.9457791949281719.
# [I 2025-04-19 13:04:38,674] Trial 20 finished with value: 0.9438378869028793 and parameters: {'C': 0.4103856613367816, 'solver': 'liblinear', 'tol': 4.826311458726362e-06, 'class_weight': 'balanced'}. Best is trial 17 with value: 0.9457791949281719.
# [I 2025-04-19 13:04:38,942] Trial 21 finished with value: 0.9457949801333543 and parameters: {'C': 3.186395432345266, 'solver': 'saga', 'tol': 1.0166845257812193e-05, 'class_weight': 'balanced'}. Best is trial 21 with value: 0.9457949801333543.
# [I 2025-04-19 13:04:39,238] Trial 22 finished with value: 0.9458087279364215 and parameters: {'C': 2.1936104784610646, 'solver': 'saga', 'tol': 1.1506170973630046e-05, 'class_weight': 'balanced'}. Best is trial 22 with value: 0.9458087279364215.
# [I 2025-04-19 13:04:39,504] Trial 23 finished with value: 0.9346834776893337 and parameters: {'C': 0.02059586006711868, 'solver': 'saga', 'tol': 1.9050710646187816e-05, 'class_weight': 'balanced'}. Best is trial 22 with value: 0.9458087279364215.
# [I 2025-04-19 13:04:39,739] Trial 24 finished with value: 0.9458094625899376 and parameters: {'C': 3.0304425204390832, 'solver': 'newton-cg', 'tol': 3.163912432932904e-06, 'class_weight': 'balanced'}. Best is trial 24 with value: 0.9458094625899376.
# [I 2025-04-19 13:04:39,975] Trial 25 finished with value: 0.9456501530935721 and parameters: {'C': 216.8882502681098, 'solver': 'newton-cg', 'tol': 2.9981644154685584e-06, 'class_weight': 'balanced'}. Best is trial 24 with value: 0.9458094625899376.
# [I 2025-04-19 13:04:40,189] Trial 26 finished with value: 0.9440901738212927 and parameters: {'C': 0.3159822388735589, 'solver': 'newton-cg', 'tol': 1.9370401792453715e-05, 'class_weight': None}. Best is trial 24 with value: 0.9458094625899376.
# [I 2025-04-19 13:04:40,424] Trial 27 finished with value: 0.9456354945573398 and parameters: {'C': 87.41257706178904, 'solver': 'newton-cg', 'tol': 1.1525219870140796e-06, 'class_weight': 'balanced'}. Best is trial 24 with value: 0.9458094625899376.
# [I 2025-04-19 13:04:40,656] Trial 28 finished with value: 0.9457514859304702 and parameters: {'C': 4.792797761658859, 'solver': 'newton-cg', 'tol': 5.511035854206632e-05, 'class_weight': 'balanced'}. Best is trial 24 with value: 0.9458094625899376.
# [I 2025-04-19 13:04:40,868] Trial 29 finished with value: 0.9379031503890153 and parameters: {'C': 0.042247207147059256, 'solver': 'newton-cg', 'tol': 3.1276062973459196e-06, 'class_weight': 'balanced'}. Best is trial 24 with value: 0.9458094625899376.
# [I 2025-04-19 13:04:41,056] Trial 30 finished with value: 0.8272026334188259 and parameters: {'C': 0.00029175233082429726, 'solver': 'liblinear', 'tol': 0.00011417449567386962, 'class_weight': 'balanced'}. Best is trial 24 with value: 0.9458094625899376.
# [I 2025-04-19 13:04:41,346] Trial 31 finished with value: 0.9458096159398989 and parameters: {'C': 3.347915674069978, 'solver': 'saga', 'tol': 1.0718773016006093e-05, 'class_weight': 'balanced'}. Best is trial 31 with value: 0.9458096159398989.
# [I 2025-04-19 13:04:41,598] Trial 32 finished with value: 0.9441049706350988 and parameters: {'C': 0.3184124475851713, 'solver': 'saga', 'tol': 1.2917867933266788e-05, 'class_weight': 'balanced'}. Best is trial 31 with value: 0.9458096159398989.
# [I 2025-04-19 13:04:41,840] Trial 33 finished with value: 0.9458391870989961 and parameters: {'C': 4.088619164006061, 'solver': 'saga', 'tol': 3.1371513932543395e-05, 'class_weight': 'balanced'}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:42,094] Trial 34 finished with value: 0.9456354327232822 and parameters: {'C': 47.44311715466228, 'solver': 'saga', 'tol': 3.322375888805085e-05, 'class_weight': 'balanced'}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:42,357] Trial 35 finished with value: 0.9457373692589418 and parameters: {'C': 8.341478880370332, 'solver': 'saga', 'tol': 4.271822985713297e-06, 'class_weight': 'balanced'}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:42,556] Trial 36 finished with value: 0.9453813680326516 and parameters: {'C': 0.7887644496060281, 'solver': 'newton-cg', 'tol': 0.00020220433243841, 'class_weight': 'balanced'}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:42,757] Trial 37 finished with value: 0.9456356865817587 and parameters: {'C': 1956.3172730165236, 'solver': 'lbfgs', 'tol': 8.905714952047846e-05, 'class_weight': 'balanced'}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:43,027] Trial 38 finished with value: 0.9456351664730498 and parameters: {'C': 17.032694082968966, 'solver': 'saga', 'tol': 1.8971292372687262e-06, 'class_weight': None}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:43,300] Trial 39 finished with value: 0.9457949588868605 and parameters: {'C': 5.366483816445911, 'solver': 'liblinear', 'tol': 5.4250651930320655e-06, 'class_weight': 'balanced'}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:43,476] Trial 40 finished with value: 0.9119340100640446 and parameters: {'C': 0.0015732349432423566, 'solver': 'lbfgs', 'tol': 1.6610228317139776e-05, 'class_weight': 'balanced'}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:43,741] Trial 41 finished with value: 0.9458245415210453 and parameters: {'C': 3.8560740223827423, 'solver': 'saga', 'tol': 1.1800570898732672e-05, 'class_weight': 'balanced'}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:43,990] Trial 42 finished with value: 0.9452498830032026 and parameters: {'C': 0.6453474121901233, 'solver': 'saga', 'tol': 3.5123256765473584e-05, 'class_weight': 'balanced'}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:44,249] Trial 43 finished with value: 0.9456062390565747 and parameters: {'C': 42.14342104507406, 'solver': 'saga', 'tol': 1.0535766226441487e-05, 'class_weight': 'balanced'}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:44,491] Trial 44 finished with value: 0.9458101056000379 and parameters: {'C': 4.552042415150275, 'solver': 'saga', 'tol': 5.3728042874773635e-05, 'class_weight': 'balanced'}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:44,753] Trial 45 finished with value: 0.9457081210202624 and parameters: {'C': 8.730535112771861, 'solver': 'saga', 'tol': 5.320814277058658e-05, 'class_weight': None}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:44,959] Trial 46 finished with value: 0.9430326621610007 and parameters: {'C': 0.1968674128238888, 'solver': 'newton-cg', 'tol': 0.000302948721484695, 'class_weight': 'balanced'}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:45,181] Trial 47 finished with value: 0.945484555405732 and parameters: {'C': 0.8438766426283285, 'solver': 'saga', 'tol': 0.00013437967243836777, 'class_weight': 'balanced'}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:45,336] Trial 48 finished with value: 0.7677360246206634 and parameters: {'C': 17.965168250129082, 'solver': 'lbfgs', 'tol': 0.09679967497476807, 'class_weight': 'balanced'}. Best is trial 33 with value: 0.9458391870989961.
# [I 2025-04-19 13:04:45,541] Trial 49 finished with value: 0.9457666497513412 and parameters: {'C': 4.775690574326326, 'solver': 'saga', 'tol': 0.002217157564804542, 'class_weight': 'balanced'}. Best is trial 33 with value: 0.9458391870989961.

# %%
print('Best trial:')
trial = study_logistic.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
    
best_model_logistic = LogisticRegression(**study_logistic.best_params)
best_model_logistic.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_logistic.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.9458391870989961
#   Params:
#     C: 4.088619164006061
#     solver: saga
#     tol: 3.1371513932543395e-05
#     class_weight: balanced
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.78      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %% [markdown]
# ### Attempt 4
#
# 1. XGBoost
# 1. Handle Class Imbalance Using SMOTE Tomek
# 1. Parameter tunning using optuna

# %%
# Define the objective function for Optuna
def objective(trial):
    param = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'verbosity': 0,
        'booster': 'gbtree',
        'lambda': trial.suggest_float('lambda', 1e-3, 10.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-3, 10.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'eta': trial.suggest_float('eta', 0.01, 0.3),
        'gamma': trial.suggest_float('gamma', 0, 10),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'max_delta_step': trial.suggest_int('max_delta_step', 0, 10)
    }

    model = XGBClassifier(**param)
    
    # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=-1)
    
    return np.mean(scores)

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective, n_trials=50)
# Out:
# [I 2025-04-19 13:05:43,359] A new study created in memory with name: no-name-ead5b167-84dc-45da-abaa-8bbfeb72a034
# [I 2025-04-19 13:05:43,941] Trial 0 finished with value: 0.9235272800988256 and parameters: {'lambda': 6.651482283337218, 'alpha': 0.001103016377071692, 'subsample': 0.42930473413920434, 'colsample_bytree': 0.45119801310926233, 'max_depth': 7, 'eta': 0.07028879806465958, 'gamma': 8.822520736965716, 'scale_pos_weight': 8.246322163632183, 'min_child_weight': 6, 'max_delta_step': 7}. Best is trial 0 with value: 0.9235272800988256.
# [I 2025-04-19 13:05:44,461] Trial 1 finished with value: 0.9672949296258242 and parameters: {'lambda': 0.013702407113638017, 'alpha': 0.5907809624850124, 'subsample': 0.9332591498251205, 'colsample_bytree': 0.7061467119859235, 'max_depth': 9, 'eta': 0.0984493623961289, 'gamma': 7.237404798530022, 'scale_pos_weight': 2.8222684172387513, 'min_child_weight': 10, 'max_delta_step': 6}. Best is trial 1 with value: 0.9672949296258242.
# [I 2025-04-19 13:05:44,899] Trial 2 finished with value: 0.9704064754344329 and parameters: {'lambda': 0.2651331292993398, 'alpha': 0.0019954306002548344, 'subsample': 0.4400533072430823, 'colsample_bytree': 0.6090832170974307, 'max_depth': 8, 'eta': 0.26592438125391066, 'gamma': 3.643782578248432, 'scale_pos_weight': 2.9411781605034513, 'min_child_weight': 1, 'max_delta_step': 8}. Best is trial 2 with value: 0.9704064754344329.
# [I 2025-04-19 13:05:45,266] Trial 3 finished with value: 0.966725010169557 and parameters: {'lambda': 0.07938129861249392, 'alpha': 0.0018419504540654807, 'subsample': 0.8927075684182093, 'colsample_bytree': 0.7029032639589958, 'max_depth': 9, 'eta': 0.2644189941268991, 'gamma': 9.530543105277925, 'scale_pos_weight': 2.8439293370164007, 'min_child_weight': 4, 'max_delta_step': 6}. Best is trial 2 with value: 0.9704064754344329.
# [I 2025-04-19 13:05:45,624] Trial 4 finished with value: 0.9482226680444371 and parameters: {'lambda': 0.0010995996867079394, 'alpha': 0.5787897817513126, 'subsample': 0.8398149285932073, 'colsample_bytree': 0.7024058681186377, 'max_depth': 4, 'eta': 0.17161997762881898, 'gamma': 8.818493006449726, 'scale_pos_weight': 9.984419614157432, 'min_child_weight': 4, 'max_delta_step': 3}. Best is trial 2 with value: 0.9704064754344329.
# [I 2025-04-19 13:05:46,042] Trial 5 finished with value: 0.968657817567073 and parameters: {'lambda': 0.007534164696547283, 'alpha': 0.03693406653056302, 'subsample': 0.8208452719061682, 'colsample_bytree': 0.4364203705655375, 'max_depth': 8, 'eta': 0.20669756017089858, 'gamma': 3.206389701389419, 'scale_pos_weight': 4.393399976272187, 'min_child_weight': 8, 'max_delta_step': 4}. Best is trial 2 with value: 0.9704064754344329.
# [I 2025-04-19 13:05:46,372] Trial 6 finished with value: 0.9641795032261541 and parameters: {'lambda': 0.6229582280188559, 'alpha': 0.04757479618863953, 'subsample': 0.8363232538005928, 'colsample_bytree': 0.5010005412864676, 'max_depth': 4, 'eta': 0.15611522606088785, 'gamma': 0.7281348118255149, 'scale_pos_weight': 1.5173684199076651, 'min_child_weight': 5, 'max_delta_step': 4}. Best is trial 2 with value: 0.9704064754344329.
# [I 2025-04-19 13:05:46,689] Trial 7 finished with value: 0.9454936918746523 and parameters: {'lambda': 6.730775048840702, 'alpha': 2.5053382173517367, 'subsample': 0.6500623362580464, 'colsample_bytree': 0.5495881567714644, 'max_depth': 3, 'eta': 0.27261499275147794, 'gamma': 9.243373366301055, 'scale_pos_weight': 9.29241099786323, 'min_child_weight': 7, 'max_delta_step': 4}. Best is trial 2 with value: 0.9704064754344329.
# [I 2025-04-19 13:05:47,011] Trial 8 finished with value: 0.942307016522529 and parameters: {'lambda': 2.7555204314571884, 'alpha': 6.049390586051248, 'subsample': 0.4721362794591314, 'colsample_bytree': 0.45377302772646905, 'max_depth': 3, 'eta': 0.25322589759702435, 'gamma': 4.724681554173613, 'scale_pos_weight': 7.377803737337392, 'min_child_weight': 3, 'max_delta_step': 7}. Best is trial 2 with value: 0.9704064754344329.
# [I 2025-04-19 13:05:47,539] Trial 9 finished with value: 0.9581571460600465 and parameters: {'lambda': 0.008071136638445312, 'alpha': 0.07583247640419971, 'subsample': 0.401998397376362, 'colsample_bytree': 0.5911644217676839, 'max_depth': 9, 'eta': 0.08763482434200116, 'gamma': 3.1664525759796005, 'scale_pos_weight': 6.923935598567701, 'min_child_weight': 8, 'max_delta_step': 5}. Best is trial 2 with value: 0.9704064754344329.
# [I 2025-04-19 13:05:48,003] Trial 10 finished with value: 0.9307855382690842 and parameters: {'lambda': 0.31698332684540315, 'alpha': 0.008062819708959786, 'subsample': 0.5717033887044869, 'colsample_bytree': 0.9187163845444346, 'max_depth': 6, 'eta': 0.017623532272386916, 'gamma': 0.4844570086684672, 'scale_pos_weight': 5.087425885286479, 'min_child_weight': 1, 'max_delta_step': 10}. Best is trial 2 with value: 0.9704064754344329.
# [I 2025-04-19 13:05:48,441] Trial 11 finished with value: 0.9701384006299746 and parameters: {'lambda': 0.03937481405241039, 'alpha': 0.010027039150249413, 'subsample': 0.7511820725670535, 'colsample_bytree': 0.8373605236577121, 'max_depth': 7, 'eta': 0.20998952400745804, 'gamma': 3.0576656573104986, 'scale_pos_weight': 4.466919851458071, 'min_child_weight': 9, 'max_delta_step': 0}. Best is trial 2 with value: 0.9704064754344329.
# [I 2025-04-19 13:05:48,855] Trial 12 finished with value: 0.9704918234947467 and parameters: {'lambda': 0.07383971788952028, 'alpha': 0.007023779120136371, 'subsample': 0.7155052867896762, 'colsample_bytree': 0.8457715154005966, 'max_depth': 6, 'eta': 0.21791703525960654, 'gamma': 3.0300793086919513, 'scale_pos_weight': 3.7528823248641827, 'min_child_weight': 1, 'max_delta_step': 0}. Best is trial 12 with value: 0.9704918234947467.
# [I 2025-04-19 13:05:49,249] Trial 13 finished with value: 0.9689235718370987 and parameters: {'lambda': 0.34781703899709976, 'alpha': 0.0054571838879255465, 'subsample': 0.6241582274156471, 'colsample_bytree': 0.8203442721078058, 'max_depth': 6, 'eta': 0.22830472534768892, 'gamma': 5.1515356037329525, 'scale_pos_weight': 3.040168599593637, 'min_child_weight': 1, 'max_delta_step': 0}. Best is trial 12 with value: 0.9704918234947467.
# [I 2025-04-19 13:05:49,639] Trial 14 finished with value: 0.9724315467559865 and parameters: {'lambda': 1.0518726001175285, 'alpha': 0.0033319982317949657, 'subsample': 0.5434002292050548, 'colsample_bytree': 0.8067981218818419, 'max_depth': 5, 'eta': 0.287672525034285, 'gamma': 1.8251612643736639, 'scale_pos_weight': 1.2162582399053021, 'min_child_weight': 2, 'max_delta_step': 10}. Best is trial 14 with value: 0.9724315467559865.
# [I 2025-04-19 13:05:50,028] Trial 15 finished with value: 0.9726350228740693 and parameters: {'lambda': 1.1430692388077814, 'alpha': 0.016756716377120978, 'subsample': 0.5396666798176111, 'colsample_bytree': 0.927545232825377, 'max_depth': 5, 'eta': 0.2956611784722596, 'gamma': 1.6864127560724738, 'scale_pos_weight': 1.0497038511358547, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 15 with value: 0.9726350228740693.
# [I 2025-04-19 13:05:50,423] Trial 16 finished with value: 0.9721821994800065 and parameters: {'lambda': 1.2859368992569524, 'alpha': 0.023178864390465518, 'subsample': 0.5367347912647445, 'colsample_bytree': 0.9869338239420119, 'max_depth': 5, 'eta': 0.2975781565761258, 'gamma': 1.5838119758958151, 'scale_pos_weight': 1.0394680534483856, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 15 with value: 0.9726350228740693.
# [I 2025-04-19 13:05:50,813] Trial 17 finished with value: 0.9715662633413634 and parameters: {'lambda': 1.6826736205105992, 'alpha': 0.19075895559468112, 'subsample': 0.5372535937981655, 'colsample_bytree': 0.7686178639318076, 'max_depth': 5, 'eta': 0.29337291174705094, 'gamma': 2.090339682311143, 'scale_pos_weight': 1.7935402226556696, 'min_child_weight': 3, 'max_delta_step': 9}. Best is trial 15 with value: 0.9726350228740693.
# [I 2025-04-19 13:05:51,212] Trial 18 finished with value: 0.9577759156643652 and parameters: {'lambda': 0.8227700003465593, 'alpha': 0.020907618849793044, 'subsample': 0.6165073353879151, 'colsample_bytree': 0.9883643219367122, 'max_depth': 5, 'eta': 0.12497305081239303, 'gamma': 5.370688018870917, 'scale_pos_weight': 6.17543763677598, 'min_child_weight': 2, 'max_delta_step': 2}. Best is trial 15 with value: 0.9726350228740693.
# [I 2025-04-19 13:05:51,564] Trial 19 finished with value: 0.9646011333236738 and parameters: {'lambda': 2.732192982996204, 'alpha': 0.0032467981137502926, 'subsample': 0.489395595221507, 'colsample_bytree': 0.9255133912440237, 'max_depth': 4, 'eta': 0.17770098250925895, 'gamma': 0.057002004334870016, 'scale_pos_weight': 2.1573987506978027, 'min_child_weight': 5, 'max_delta_step': 10}. Best is trial 15 with value: 0.9726350228740693.
# [I 2025-04-19 13:05:52,024] Trial 20 finished with value: 0.9756201984919531 and parameters: {'lambda': 0.1506607739498928, 'alpha': 0.1436301768844058, 'subsample': 0.6969180755516147, 'colsample_bytree': 0.8951255110696, 'max_depth': 10, 'eta': 0.24102565066686626, 'gamma': 1.674191551197877, 'scale_pos_weight': 1.121919604172791, 'min_child_weight': 2, 'max_delta_step': 2}. Best is trial 20 with value: 0.9756201984919531.
# [I 2025-04-19 13:05:52,474] Trial 21 finished with value: 0.9753131994749652 and parameters: {'lambda': 0.13393161647831744, 'alpha': 0.1160209138625676, 'subsample': 0.6760427232592011, 'colsample_bytree': 0.8936613907155408, 'max_depth': 10, 'eta': 0.24469355093283296, 'gamma': 1.8008016450217776, 'scale_pos_weight': 1.1055762337402415, 'min_child_weight': 2, 'max_delta_step': 2}. Best is trial 20 with value: 0.9756201984919531.
# [I 2025-04-19 13:05:53,011] Trial 22 finished with value: 0.975018744055649 and parameters: {'lambda': 0.1815455671704868, 'alpha': 0.2137859200752691, 'subsample': 0.6958616100107955, 'colsample_bytree': 0.9198193550166922, 'max_depth': 10, 'eta': 0.24069977911704582, 'gamma': 2.0207143410363204, 'scale_pos_weight': 2.1305609079974985, 'min_child_weight': 2, 'max_delta_step': 2}. Best is trial 20 with value: 0.9756201984919531.
# [I 2025-04-19 13:05:53,431] Trial 23 finished with value: 0.971943764083497 and parameters: {'lambda': 0.15145979119626413, 'alpha': 0.20212429644233187, 'subsample': 0.7304400883175921, 'colsample_bytree': 0.8834894566919237, 'max_depth': 10, 'eta': 0.24031166051065572, 'gamma': 4.288542303135422, 'scale_pos_weight': 2.1946393557774435, 'min_child_weight': 2, 'max_delta_step': 1}. Best is trial 20 with value: 0.9756201984919531.
# [I 2025-04-19 13:05:53,848] Trial 24 finished with value: 0.9700977856564297 and parameters: {'lambda': 0.03088886513880158, 'alpha': 0.5523197474417291, 'subsample': 0.6820035857677604, 'colsample_bytree': 0.8828452769465767, 'max_depth': 10, 'eta': 0.19158589781707352, 'gamma': 6.374708997038289, 'scale_pos_weight': 2.1721185180507243, 'min_child_weight': 4, 'max_delta_step': 3}. Best is trial 20 with value: 0.9756201984919531.
# [I 2025-04-19 13:05:54,380] Trial 25 finished with value: 0.9763349525275297 and parameters: {'lambda': 0.1408475064917636, 'alpha': 0.1965399459560355, 'subsample': 0.7695548974787902, 'colsample_bytree': 0.9622465329697146, 'max_depth': 10, 'eta': 0.24036184859215612, 'gamma': 1.1083149469766305, 'scale_pos_weight': 3.7635495509858106, 'min_child_weight': 2, 'max_delta_step': 1}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:05:54,999] Trial 26 finished with value: 0.9751621683589061 and parameters: {'lambda': 0.0373647733741653, 'alpha': 0.08202618675247408, 'subsample': 0.7895048862097058, 'colsample_bytree': 0.7622177606741956, 'max_depth': 10, 'eta': 0.14226733633232996, 'gamma': 0.8501423373146347, 'scale_pos_weight': 3.5519505625917738, 'min_child_weight': 2, 'max_delta_step': 1}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:05:55,499] Trial 27 finished with value: 0.972101003482203 and parameters: {'lambda': 0.1397303349935122, 'alpha': 1.064824610671527, 'subsample': 0.7711981774067297, 'colsample_bytree': 0.9924534456701666, 'max_depth': 9, 'eta': 0.18844358942738287, 'gamma': 2.495010947765382, 'scale_pos_weight': 5.266573394591718, 'min_child_weight': 6, 'max_delta_step': 1}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:05:55,980] Trial 28 finished with value: 0.9733058084903264 and parameters: {'lambda': 0.018145537842807983, 'alpha': 0.15989651338583266, 'subsample': 0.6586192296941625, 'colsample_bytree': 0.8691127398076675, 'max_depth': 8, 'eta': 0.23327883956048243, 'gamma': 1.1259928113461748, 'scale_pos_weight': 3.6666353570150303, 'min_child_weight': 4, 'max_delta_step': 3}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:05:56,641] Trial 29 finished with value: 0.9505499152807863 and parameters: {'lambda': 0.07148884365202716, 'alpha': 0.3513573583403837, 'subsample': 0.6038723594127611, 'colsample_bytree': 0.7870130823405523, 'max_depth': 10, 'eta': 0.03548370327879739, 'gamma': 1.2788808228506205, 'scale_pos_weight': 6.0833893654340905, 'min_child_weight': 5, 'max_delta_step': 1}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:05:57,050] Trial 30 finished with value: 0.9696530699640626 and parameters: {'lambda': 0.4885916691769132, 'alpha': 1.871417143714666, 'subsample': 0.9966217811359038, 'colsample_bytree': 0.9476457334683435, 'max_depth': 9, 'eta': 0.19818858314610127, 'gamma': 4.059242338600493, 'scale_pos_weight': 4.367609170043284, 'min_child_weight': 3, 'max_delta_step': 3}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:05:57,715] Trial 31 finished with value: 0.9738143036459981 and parameters: {'lambda': 0.039739700486921985, 'alpha': 0.07656250067310388, 'subsample': 0.7981743019237296, 'colsample_bytree': 0.6467780808793401, 'max_depth': 10, 'eta': 0.12216711506875569, 'gamma': 0.16411922835971238, 'scale_pos_weight': 3.6680053947072446, 'min_child_weight': 2, 'max_delta_step': 1}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:05:58,374] Trial 32 finished with value: 0.9744161040578986 and parameters: {'lambda': 0.10825024561180156, 'alpha': 0.10737974727125134, 'subsample': 0.8769311682424717, 'colsample_bytree': 0.7481983733464492, 'max_depth': 10, 'eta': 0.13415171566799589, 'gamma': 1.0016134428075518, 'scale_pos_weight': 3.389014463843313, 'min_child_weight': 2, 'max_delta_step': 1}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:05:58,920] Trial 33 finished with value: 0.9738758079639765 and parameters: {'lambda': 0.016773757099174863, 'alpha': 0.04938029816025989, 'subsample': 0.7796741770435068, 'colsample_bytree': 0.7467357508377562, 'max_depth': 9, 'eta': 0.15361436938648942, 'gamma': 2.469600916103282, 'scale_pos_weight': 2.447319753016219, 'min_child_weight': 1, 'max_delta_step': 0}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:05:59,534] Trial 34 finished with value: 0.9746973185268243 and parameters: {'lambda': 0.0034692160716854937, 'alpha': 0.3425254881575903, 'subsample': 0.7420452230088062, 'colsample_bytree': 0.9500840182114727, 'max_depth': 8, 'eta': 0.2556562887609624, 'gamma': 0.7397758112471553, 'scale_pos_weight': 2.845867092178398, 'min_child_weight': 1, 'max_delta_step': 2}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:06:00,158] Trial 35 finished with value: 0.9742002094763954 and parameters: {'lambda': 0.05329840386141397, 'alpha': 0.09229124197628545, 'subsample': 0.8679981194587658, 'colsample_bytree': 0.662337387383684, 'max_depth': 9, 'eta': 0.273785622022991, 'gamma': 2.5490394226312114, 'scale_pos_weight': 1.5993783103191823, 'min_child_weight': 4, 'max_delta_step': 1}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:06:00,961] Trial 36 finished with value: 0.9733014806608223 and parameters: {'lambda': 0.024439317166233106, 'alpha': 0.3463018001358849, 'subsample': 0.9220870432829101, 'colsample_bytree': 0.8691495601456581, 'max_depth': 10, 'eta': 0.09829930704012987, 'gamma': 1.3548936147179593, 'scale_pos_weight': 4.0850445353078495, 'min_child_weight': 3, 'max_delta_step': 5}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:06:01,503] Trial 37 finished with value: 0.9650956424405904 and parameters: {'lambda': 0.22772394443271135, 'alpha': 1.0295162058752871, 'subsample': 0.7959831015861751, 'colsample_bytree': 0.9026343464450378, 'max_depth': 8, 'eta': 0.06470574028918082, 'gamma': 7.339767359013708, 'scale_pos_weight': 2.6296086198244453, 'min_child_weight': 2, 'max_delta_step': 3}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:06:02,115] Trial 38 finished with value: 0.9727015046643116 and parameters: {'lambda': 0.011659699065888804, 'alpha': 0.030980589030459544, 'subsample': 0.680808137462713, 'colsample_bytree': 0.9640917187937672, 'max_depth': 10, 'eta': 0.16411882233362346, 'gamma': 0.47369425689934097, 'scale_pos_weight': 4.868024031410869, 'min_child_weight': 10, 'max_delta_step': 4}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:06:02,590] Trial 39 finished with value: 0.9700924710336999 and parameters: {'lambda': 0.003019069709292102, 'alpha': 0.055765640831309436, 'subsample': 0.841365035617131, 'colsample_bytree': 0.8457846108111104, 'max_depth': 7, 'eta': 0.14499883948817244, 'gamma': 0.025539433565884062, 'scale_pos_weight': 5.6899324406569765, 'min_child_weight': 1, 'max_delta_step': 6}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:06:02,990] Trial 40 finished with value: 0.9679251190338961 and parameters: {'lambda': 0.09933480943461404, 'alpha': 0.7397752393481394, 'subsample': 0.7155519580208821, 'colsample_bytree': 0.7283740431432253, 'max_depth': 9, 'eta': 0.22114777437958447, 'gamma': 7.96310256834471, 'scale_pos_weight': 3.130198620546601, 'min_child_weight': 4, 'max_delta_step': 2}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:06:03,545] Trial 41 finished with value: 0.9753998909721474 and parameters: {'lambda': 0.19361651921259657, 'alpha': 0.25500650889546717, 'subsample': 0.6882986241129274, 'colsample_bytree': 0.9023795939559861, 'max_depth': 10, 'eta': 0.2364113469944266, 'gamma': 2.120677358038983, 'scale_pos_weight': 1.724115154335971, 'min_child_weight': 2, 'max_delta_step': 2}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:06:03,998] Trial 42 finished with value: 0.9750488703439798 and parameters: {'lambda': 0.49642045720858585, 'alpha': 0.11465086067962917, 'subsample': 0.6547662369284368, 'colsample_bytree': 0.9611429401904341, 'max_depth': 9, 'eta': 0.25397927762948, 'gamma': 2.216244011915524, 'scale_pos_weight': 1.856815707264889, 'min_child_weight': 2, 'max_delta_step': 0}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:06:04,402] Trial 43 finished with value: 0.973264031509759 and parameters: {'lambda': 0.2538209178712416, 'alpha': 0.13991656772258643, 'subsample': 0.7686479259665807, 'colsample_bytree': 0.8966577052297376, 'max_depth': 10, 'eta': 0.26706236887422313, 'gamma': 3.572502017691192, 'scale_pos_weight': 1.5329977382022377, 'min_child_weight': 3, 'max_delta_step': 3}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:06:04,924] Trial 44 finished with value: 0.9760737683476344 and parameters: {'lambda': 0.059373381076008126, 'alpha': 0.2785804370608909, 'subsample': 0.8091864832759318, 'colsample_bytree': 0.7978535089269939, 'max_depth': 9, 'eta': 0.20894940374344664, 'gamma': 0.9530756644464706, 'scale_pos_weight': 1.3906001656113216, 'min_child_weight': 1, 'max_delta_step': 4}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:06:05,363] Trial 45 finished with value: 0.9740399492446237 and parameters: {'lambda': 0.0630440376534559, 'alpha': 0.2899127924105691, 'subsample': 0.8180669121324732, 'colsample_bytree': 0.8110384572736278, 'max_depth': 9, 'eta': 0.24452200747985747, 'gamma': 2.801663879839152, 'scale_pos_weight': 1.3489820350929767, 'min_child_weight': 1, 'max_delta_step': 5}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:06:05,774] Trial 46 finished with value: 0.9725305903298779 and parameters: {'lambda': 0.11452340289258277, 'alpha': 0.4896071976335531, 'subsample': 0.7414058568744181, 'colsample_bytree': 0.8580864391094453, 'max_depth': 8, 'eta': 0.20799163430021053, 'gamma': 3.4750512636466255, 'scale_pos_weight': 1.7566818453520043, 'min_child_weight': 1, 'max_delta_step': 4}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:06:06,339] Trial 47 finished with value: 0.9720271540270183 and parameters: {'lambda': 0.3613235780236731, 'alpha': 2.1307216645495672, 'subsample': 0.7122960684895605, 'colsample_bytree': 0.7940676001522907, 'max_depth': 10, 'eta': 0.2255576850751795, 'gamma': 1.8362350008991164, 'scale_pos_weight': 8.684909125809657, 'min_child_weight': 7, 'max_delta_step': 7}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:06:06,838] Trial 48 finished with value: 0.973528142517925 and parameters: {'lambda': 0.16916996946550816, 'alpha': 6.70035388091984, 'subsample': 0.5916405445472683, 'colsample_bytree': 0.831066367129466, 'max_depth': 9, 'eta': 0.28014030092021536, 'gamma': 1.3408282239852523, 'scale_pos_weight': 1.290280803978372, 'min_child_weight': 3, 'max_delta_step': 6}. Best is trial 25 with value: 0.9763349525275297.
# [I 2025-04-19 13:06:07,474] Trial 49 finished with value: 0.9758529493337559 and parameters: {'lambda': 0.05481476842947097, 'alpha': 0.2591342444797571, 'subsample': 0.653939850098443, 'colsample_bytree': 0.9034431868309494, 'max_depth': 10, 'eta': 0.25487946373645054, 'gamma': 0.6801205079464634, 'scale_pos_weight': 2.495763813393965, 'min_child_weight': 1, 'max_delta_step': 4}. Best is trial 25 with value: 0.9763349525275297.

# %%
print('Best trial:')
trial = study_xgb.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
    
best_params = study_xgb.best_params
best_model_xgb = XGBClassifier(**best_params)
best_model_xgb.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_xgb.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.9763349525275297
#   Params:
#     lambda: 0.1408475064917636
#     alpha: 0.1965399459560355
#     subsample: 0.7695548974787902
#     colsample_bytree: 0.9622465329697146
#     max_depth: 10
#     eta: 0.24036184859215612
#     gamma: 1.1083149469766305
#     scale_pos_weight: 3.7635495509858106
#     min_child_weight: 2
#     max_delta_step: 1
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98     11423
#            1       0.70      0.87      0.77      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.84      0.92      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# #### Model Evaluation : ROC/AUC

# %%
y_pred = best_model_logistic.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.78      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
from sklearn.metrics import roc_curve

probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, probabilities)

fpr[:5], tpr[:5], thresholds[:5]
# Out:
# (array([0.        , 0.        , 0.        , 0.00008754, 0.00008754]),
#  array([0.        , 0.0009311 , 0.16014898, 0.16014898, 0.17690875]),
#  array([       inf, 1.        , 0.99946642, 0.99945492, 0.99933234]))

# %%
from sklearn.metrics import auc

area = auc(fpr, tpr)
area
# Out:
# 0.9836728831748681

# %%
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % area)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# #### Model Evaluation : Rankordering, KS statistic, Gini coeff

# %%
probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]

df_eval = pd.DataFrame({
    'Default Truth': y_test,
    'Default Probability': probabilities
})
df_eval.head(3)
# Out:
#        Default Truth  Default Probability
# 19205              0                0.531
# 15514              0                0.000
# 30367              0                0.006

# %%
df_eval['Decile'] = pd.qcut(df_eval['Default Probability'], 10, labels=False, duplicates='drop')
df_eval.head(3)
# Out:
#        Default Truth  Default Probability  Decile
# 19205              0                0.531       8
# 15514              0                0.000       2
# 30367              0                0.006       6

# %%
df_eval[df_eval.Decile==8]['Default Probability'].describe()
# Out:
# count   1250.000
# mean       0.485
# std        0.183
# min        0.212
# 25%        0.316
# 50%        0.467
# 75%        0.641
# max        0.820
# Name: Default Probability, dtype: float64

# %%
df_decile = df_eval.groupby('Decile').apply(lambda x: pd.Series({
    'Minimum Probability': x['Default Probability'].min(),
    'Maximum Probability': x['Default Probability'].max(),
    'Events': x['Default Truth'].sum(),
    'Non-events': x['Default Truth'].count() - x['Default Truth'].sum(),    
}))
df_decile.reset_index(inplace=True)
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.004   0.000    1249.000
# 6       6                0.004                0.029   5.000    1245.000
# 7       7                0.029                0.212  11.000    1238.000
# 8       8                0.212                0.820 159.000    1091.000
# 9       9                0.820                1.000 899.000     351.000

# %%
df_decile['Event Rate'] = df_decile['Events']*100 / (df_decile['Events']+df_decile['Non-events'])
df_decile['Non-event Rate'] = df_decile['Non-events']*100 / (df_decile['Events']+df_decile['Non-events'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.004   0.000    1249.000
# 6       6                0.004                0.029   5.000    1245.000
# 7       7                0.029                0.212  11.000    1238.000
# 8       8                0.212                0.820 159.000    1091.000
# 9       9                0.820                1.000 899.000     351.000
#
#    Event Rate  Non-event Rate
# 0       0.000         100.000
# 1       0.000         100.000
# 2       0.000         100.000
# 3       0.000         100.000
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.400          99.600
# 7       0.881          99.119
# 8      12.720          87.280
# 9      71.920          28.080

# %%
df_decile = df_decile.sort_values(by='Decile', ascending=False).reset_index(drop=True)
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.820                1.000 899.000     351.000
# 1       8                0.212                0.820 159.000    1091.000
# 2       7                0.029                0.212  11.000    1238.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate
# 0      71.920          28.080
# 1      12.720          87.280
# 2       0.881          99.119
# 3       0.400          99.600
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.000         100.000
# 7       0.000         100.000
# 8       0.000         100.000
# 9       0.000         100.000

# %%
df_decile['Cum Events'] =  df_decile['Events'].cumsum()
df_decile['Cum Non-events'] =  df_decile['Non-events'].cumsum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.820                1.000 899.000     351.000
# 1       8                0.212                0.820 159.000    1091.000
# 2       7                0.029                0.212  11.000    1238.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events
# 0      71.920          28.080     899.000         351.000
# 1      12.720          87.280    1058.000        1442.000
# 2       0.881          99.119    1069.000        2680.000
# 3       0.400          99.600    1074.000        3925.000
# 4       0.000         100.000    1074.000        5174.000
# 5       0.000         100.000    1074.000        6424.000
# 6       0.000         100.000    1074.000        7674.000
# 7       0.000         100.000    1074.000        8923.000
# 8       0.000         100.000    1074.000       10173.000
# 9       0.000         100.000    1074.000       11423.000

# %%
df_decile['Cum Event Rate'] = df_decile['Cum Events'] * 100 / df_decile['Events'].sum()
df_decile['Cum Non-event Rate'] = df_decile['Cum Non-events']*100 / df_decile['Non-events'].sum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.820                1.000 899.000     351.000
# 1       8                0.212                0.820 159.000    1091.000
# 2       7                0.029                0.212  11.000    1238.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events  Cum Event Rate  \
# 0      71.920          28.080     899.000         351.000          83.706
# 1      12.720          87.280    1058.000        1442.000          98.510
# 2       0.881          99.119    1069.000        2680.000          99.534
# 3       0.400          99.600    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate
# 0               3.073
# 1              12.624
# 2              23.461
# 3              34.361
# 4              45.295
# 5              56.237
# 6              67.180
# 7              78.114
# 8              89.057
# 9             100.000

# %%
df_decile['KS'] = abs(df_decile['Cum Event Rate'] - df_decile['Cum Non-event Rate'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.820                1.000 899.000     351.000
# 1       8                0.212                0.820 159.000    1091.000
# 2       7                0.029                0.212  11.000    1238.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events  Cum Event Rate  \
# 0      71.920          28.080     899.000         351.000          83.706
# 1      12.720          87.280    1058.000        1442.000          98.510
# 2       0.881          99.119    1069.000        2680.000          99.534
# 3       0.400          99.600    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate     KS
# 0               3.073 80.633
# 1              12.624 85.887
# 2              23.461 76.073
# 3              34.361 65.639
# 4              45.295 54.705
# 5              56.237 43.763
# 6              67.180 32.820
# 7              78.114 21.886
# 8              89.057 10.943
# 9             100.000  0.000

# %% [markdown]
# To assess whether rank ordering is followed, we should look at whether higher deciles (those with higher predicted probabilities) have higher event rates compared to lower deciles. Rank ordering means that as you move from the top decile to the bottom decile, the event rate should generally decrease.
#
# Non-Events - termed as good (customers) who do not default. Events - termed as bad (customers) who default.
#
# Events and Non-Events terms are interchanged based on usecase to usecase.
#
# eg: for marketing usecase, which customer to reach out (who will take loan based on offers) will be events - here it will termed as good, and the customers who will not take loans will be non-events (bad).
#
# **Insights from the Decile Table**
#
# 1. Top Deciles
#
# * The first decile (Decile 9) has a high event rate of 72.00% and a non-event rate of 28.00%. This indicates that the model is highly confident in predicting events in this decile.
# * The second decile (Decile 8) also shows a significant event rate of 12.72%, with a cumulative event rate reaching 98.6%.
#
# 2. Middle Deciles:
#
# * Deciles 7 and 6 show a significant drop in event rates
#
# 3. Lower Deciles:
#
# * Deciles 5 to 0 show zero events, with all predictions being non-events. These deciles collectively have a non-event rate of 100%.
#
# 4. KS Statistic:
#
# * The KS statistic, which is the maximum difference between cumulative event rates and cumulative non-event rates, is highest at Decile 8 with a value of 85.98%. This suggests that the model performs best at distinguishing between events and non-events up to this decile.
#
# * The KS value gradually decreases in the following deciles, indicating a decrease in model performance for distinguishing between events and non-events.
#
# **KS Value**
#
# The highest KS value is 85.98%, found at Decile 8. This indicates that the model's performance in distinguishing between events and non-events is most significant at this decile. (If KS is in top 3 decile and score above 40, it is considered a good predictive model.)

# %%
gini_coefficient = 2 * area - 1

print("AUC:", area)
print("Gini Coefficient:", gini_coefficient)
# Out:
# AUC: 0.9836728831748681
# Gini Coefficient: 0.9673457663497362

# %% [markdown]
# AUC of 0.98: The model is very good at distinguishing between events and non-events.
#
# Gini coefficient of 0.96: This further confirms that the model is highly effective in its predictions, with almost perfect rank ordering capability.
#
# The Gini coefficient ranges from -1 to 1, where a value closer to 1 signifies a perfect model, 0 indicates a model with no discriminative power, and -1 signifies a perfectly incorrect model.

# %%
final_model = best_model_logistic

feature_importance = final_model.coef_[0]

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_encoded.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %% [markdown]
# #### Save the Model

# %%
X_test_encoded.head(2)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346               0.755                    0.333
# 15514 0.481               0.226                    1.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 19205                     0.990           0.550              0.000
# 15514                     0.323           0.220              0.000
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 19205                    0.000                     1                      0
# 15514                    0.000                     1                      0
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 19205                       0                  1                      0
# 15514                       1                  0                      0
#
#        loan_type_Unsecured
# 19205                    0
# 15514                    0

# %%
X_test_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
col_to_scale
# Out:
# ['age',
#  'number_of_dependants',
#  'years_at_current_address',
#  'sanction_amount',
#  'processing_fee',
#  'gst',
#  'net_disbursement',
#  'loan_tenure_months',
#  'principal_outstanding',
#  'bank_balance_at_application',
#  'number_of_open_accounts',
#  'number_of_closed_accounts',
#  'enquiry_count',
#  'credit_utilization_ratio',
#  'loan_to_income',
#  'delinquency_ratio',
#  'avg_dpd_per_delinquency']

# %%
X_train_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
from joblib import dump

model_data = {
    'model': final_model,
    'features': X_train_encoded.columns,
    'scaler': scaler,
    'cols_to_scale': col_to_scale
}
dump(model_data, 'artifacts/model_data.joblib')
# Out:
# ['artifacts/model_data.joblib']

# %%
final_model.coef_, final_model.intercept_
# Out:
# (array([[ 0.00748189,  0.63501463,  1.18454907, 15.98961889, 17.53107506,
#          13.77185429,  2.05005001, -1.8444044 ,  1.85621296,  1.00305744,
#          -3.49966378,  1.0640657 ,  1.0640657 ]]),
#  array([-20.88318993]))
